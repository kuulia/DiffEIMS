# %%
import pandas as pd

# %%
df = pd.read_csv('database.csv', low_memory=False, on_bad_lines='skip')
df.head()
# Out:
#    Index                  Name Synon Campaign/Experimental_Source  \
# 0      0   UNK_AHG_LY_ACEDOX_1   NaN         Laboratory Oxidation
# 1      1   UNK_AHG_LY_ACEDOX_2   NaN         Laboratory Oxidation
# 2      2   UNK_AHG_LY_ACEDOX_3   NaN         Laboratory Oxidation
# 3      3   UNK_AHG_LY_ACEDOX_4   NaN         Laboratory Oxidation
# 4      4  UNK_AHG_LY_ACEDOX_13   NaN         Laboratory Oxidation
#
#      Experimental_Conditions    UID Contributor_ID Comments Suspected_Matches  \
# 0  ER721GF3 (a-cedrene + O3)  LDY-0            NaN      NaN               NaN
# 1  ER721GF3 (a-cedrene + O3)  LDY-1            NaN      NaN               NaN
# 2  ER721GF3 (a-cedrene + O3)  LDY-2            NaN      NaN               NaN
# 3  ER721GF3 (a-cedrene + O3)  LDY-3            NaN      NaN               NaN
# 4  ER721GF3 (a-cedrene + O3)  LDY-4            NaN      NaN               NaN
#
#   Confirmed_Matches  ...                   Oven_temp  \
# 0               NaN  ...  40 C to 320 C at 3.5 C/min
# 1               NaN  ...  40 C to 320 C at 3.5 C/min
# 2               NaN  ...  40 C to 320 C at 3.5 C/min
# 3               NaN  ...  40 C to 320 C at 3.5 C/min
# 4               NaN  ...  40 C to 320 C at 3.5 C/min
#
#                                         Publications  Contributor  \
# 0  Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...  Lindsay Yee
# 1  Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...  Lindsay Yee
# 2  Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...  Lindsay Yee
# 3  Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...  Lindsay Yee
# 4  Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...  Lindsay Yee
#
#    Date_of_Entry  Num Peaks              5_Highest_Intensity_MZ  Base_Peak  \
# 0     11/16/2020      198.0   [73.0, 149.0, 75.0, 267.0, 177.0]       73.0
# 1     11/16/2020      175.0  [149.0, 73.0, 309.0, 191.0, 281.0]      149.0
# 2     11/16/2020      203.0   [73.0, 149.0, 192.0, 43.0, 117.0]       73.0
# 3     11/16/2020      195.0  [73.0, 240.0, 225.0, 150.0, 192.0]       73.0
# 4     11/16/2020      162.0  [149.0, 221.0, 73.0, 107.0, 121.0]      149.0
#
#                                                   MS  \
# 0  29 5.0 ; 39 11.0 ; 40 1.0 ; 41 50.0 ; 42 3.0 ;...
# 1  29 4.0 ; 39 8.0 ; 40 1.0 ; 41 53.0 ; 42 3.0 ; ...
# 2  29 14.0 ; 31 1.0 ; 39 45.0 ; 40 6.0 ; 41 170.0...
# 3  29 11.0 ; 31 1.0 ; 38 1.0 ; 39 36.0 ; 40 5.0 ;...
# 4  29 7.0 ; 39 16.0 ; 40 2.0 ; 41 83.0 ; 42 5.0 ;...
#
#                                             X-Values  \
# 0  [ 29.  39.  40.  41.  42.  43.  44.  45.  46. ...
# 1  [ 29.  39.  40.  41.  42.  43.  44.  45.  46. ...
# 2  [ 29.  31.  39.  40.  41.  42.  43.  44.  45. ...
# 3  [ 29.  31.  38.  39.  40.  41.  42.  43.  44. ...
# 4  [ 29.  39.  40.  41.  42.  43.  44.  45.  46. ...
#
#                                             Y-Values
# 0  [  5.  11.   1.  50.   3.  29.   9.  80.   4. ...
# 1  [  4.   8.   1.  53.   3.  32.   8.  61.   3. ...
# 2  [ 14.   1.  45.   6. 170.  14. 694.  32. 139. ...
# 3  [ 11.   1.   1.  36.   5. 116.  10. 395.  19. ...
# 4  [  7.  16.   2.  83.   5.  38.   7.  34.   2. ...
#
# [5 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['Index', 'Name', 'Synon', 'Campaign/Experimental_Source',
#        'Experimental_Conditions', 'UID', 'Contributor_ID', 'Comments',
#        'Suspected_Matches', 'Confirmed_Matches', 'Predicted_Matches',
#        'Compound_Structural_Info', 'Formula', 'MW', 'MW_Prediction',
#        'ExactMass', 'VUV_Exact_Mass', 'CAS#', 'Ch3MS-RF_Cnum.p',
#        'Ch3MS-RF_OC.p', 'Ch3MS-RF_OSc.p', 'Ch3MS-RF_VP.p', 'Column_Type',
#        'Retention_index', 'd_alkane_RTI', 'n_alkane_RTI', 'Instrument',
#        'Ionization', 'Injection_method', 'Derivatization_Agent', 'GC_column',
#        'Oven_temp', 'Publications', 'Contributor', 'Date_of_Entry',
#        'Num Peaks', '5_Highest_Intensity_MZ', 'Base_Peak', 'MS', 'X-Values',
#        'Y-Values'],
#       dtype='object')

# %%
df
# Out:
#        Index                                     Name Synon  \
# 0          0                      UNK_AHG_LY_ACEDOX_1   NaN
# 1          1                      UNK_AHG_LY_ACEDOX_2   NaN
# 2          2                      UNK_AHG_LY_ACEDOX_3   NaN
# 3          3                      UNK_AHG_LY_ACEDOX_4   NaN
# 4          4                     UNK_AHG_LY_ACEDOX_13   NaN
# ...      ...                                      ...   ...
# 25684  26902                      UNK_AHG_HZ_SOAS_749   NaN
# 25685  26903                      UNK_AHG_HZ_SOAS_815   NaN
# 25686  26904                      UNK_AHG_HZ_SOAS_829   NaN
# 25687  26905  2,3-erythro-dihydroxyglutaric acid iso1   NaN
# 25688  26906                       UNK_AHG_HZ_SOAS_49   NaN
#
#       Campaign/Experimental_Source    Experimental_Conditions        UID  \
# 0             Laboratory Oxidation  ER721GF3 (a-cedrene + O3)      LDY-0
# 1             Laboratory Oxidation  ER721GF3 (a-cedrene + O3)      LDY-1
# 2             Laboratory Oxidation  ER721GF3 (a-cedrene + O3)      LDY-2
# 3             Laboratory Oxidation  ER721GF3 (a-cedrene + O3)      LDY-3
# 4             Laboratory Oxidation  ER721GF3 (a-cedrene + O3)      LDY-4
# ...                            ...                        ...        ...
# 25684                    SOAS 2013                        NaN  LDY-26907
# 25685                    SOAS 2013                        NaN  LDY-26908
# 25686                    SOAS 2013                        NaN  LDY-26909
# 25687                    SOAS 2013                        NaN  LDY-26910
# 25688                    SOAS 2013                        NaN  LDY-26911
#
#       Contributor_ID Comments Suspected_Matches Confirmed_Matches  ...  \
# 0                NaN      NaN               NaN               NaN  ...
# 1                NaN      NaN               NaN               NaN  ...
# 2                NaN      NaN               NaN               NaN  ...
# 3                NaN      NaN               NaN               NaN  ...
# 4                NaN      NaN               NaN               NaN  ...
# ...              ...      ...               ...               ...  ...
# 25684            NaN      NaN               NaN               NaN  ...
# 25685            NaN      NaN               NaN               NaN  ...
# 25686            NaN      NaN               NaN               NaN  ...
# 25687            NaN      NaN               NaN               NaN  ...
# 25688            NaN      NaN               NaN               NaN  ...
#
#                         Oven_temp  \
# 0      40 C to 320 C at 3.5 C/min
# 1      40 C to 320 C at 3.5 C/min
# 2      40 C to 320 C at 3.5 C/min
# 3      40 C to 320 C at 3.5 C/min
# 4      40 C to 320 C at 3.5 C/min
# ...                           ...
# 25684  40 C to 320 C at 3.5 C/min
# 25685  40 C to 320 C at 3.5 C/min
# 25686  40 C to 320 C at 3.5 C/min
# 25687  40 C to 320 C at 3.5 C/min
# 25688  40 C to 320 C at 3.5 C/min
#
#                                             Publications   Contributor  \
# 0      Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...   Lindsay Yee
# 1      Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...   Lindsay Yee
# 2      Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...   Lindsay Yee
# 3      Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...   Lindsay Yee
# 4      Yee, L. D., Isaacman-Vanwertz, G., Wernis, R. ...   Lindsay Yee
# ...                                                  ...           ...
# 25684  Zhang, H., Yee, L. D., Lee, B. H., Curtis, M. ...  Haofei Zhang
# 25685  Zhang, H., Yee, L. D., Lee, B. H., Curtis, M. ...  Haofei Zhang
# 25686  Zhang, H., Yee, L. D., Lee, B. H., Curtis, M. ...  Haofei Zhang
# 25687  Zhang, H., Yee, L. D., Lee, B. H., Curtis, M. ...  Haofei Zhang
# 25688  Zhang, H., Yee, L. D., Lee, B. H., Curtis, M. ...  Haofei Zhang
#
#        Date_of_Entry  Num Peaks              5_Highest_Intensity_MZ  \
# 0         11/16/2020      198.0   [73.0, 149.0, 75.0, 267.0, 177.0]
# 1         11/16/2020      175.0  [149.0, 73.0, 309.0, 191.0, 281.0]
# 2         11/16/2020      203.0   [73.0, 149.0, 192.0, 43.0, 117.0]
# 3         11/16/2020      195.0  [73.0, 240.0, 225.0, 150.0, 192.0]
# 4         11/16/2020      162.0  [149.0, 221.0, 73.0, 107.0, 121.0]
# ...              ...        ...                                 ...
# 25684      4/27/2021      154.0                                 NaN
# 25685      4/27/2021      229.0                                 NaN
# 25686      4/27/2021      222.0                                 NaN
# 25687      4/27/2021      255.0                                 NaN
# 25688      4/27/2021      295.0                                 NaN
#
#        Base_Peak                                                 MS  \
# 0           73.0  29 5.0 ; 39 11.0 ; 40 1.0 ; 41 50.0 ; 42 3.0 ;...
# 1          149.0  29 4.0 ; 39 8.0 ; 40 1.0 ; 41 53.0 ; 42 3.0 ; ...
# 2           73.0  29 14.0 ; 31 1.0 ; 39 45.0 ; 40 6.0 ; 41 170.0...
# 3           73.0  29 11.0 ; 31 1.0 ; 38 1.0 ; 39 36.0 ; 40 5.0 ;...
# 4          149.0  29 7.0 ; 39 16.0 ; 40 2.0 ; 41 83.0 ; 42 5.0 ;...
# ...          ...                                                ...
# 25684        NaN  29 7.0 ; 31 6.0 ; 39 4.0 ; 40 1.0 ; 41 8.0 ; 4...
# 25685        NaN  29 7.0 ; 30 2.0 ; 31 3.0 ; 32 14.0 ; 33 1.0 ; ...
# 25686        NaN  29 7.0 ; 30 1.0 ; 31 1.0 ; 32 1.0 ; 37 1.0 ; 3...
# 25687        NaN  29 1.0 ; 31 1.0 ; 39 1.0 ; 41 3.0 ; 42 3.0 ; 4...
# 25688        NaN  29 2.0 ; 30 1.0 ; 32 2.0 ; 33 1.0 ; 34 1.0 ; 3...
#
#                                                 X-Values  \
# 0      [ 29.  39.  40.  41.  42.  43.  44.  45.  46. ...
# 1      [ 29.  39.  40.  41.  42.  43.  44.  45.  46. ...
# 2      [ 29.  31.  39.  40.  41.  42.  43.  44.  45. ...
# 3      [ 29.  31.  38.  39.  40.  41.  42.  43.  44. ...
# 4      [ 29.  39.  40.  41.  42.  43.  44.  45.  46. ...
# ...                                                  ...
# 25684                                                NaN
# 25685                                                NaN
# 25686                                                NaN
# 25687                                                NaN
# 25688                                                NaN
#
#                                                 Y-Values
# 0      [  5.  11.   1.  50.   3.  29.   9.  80.   4. ...
# 1      [  4.   8.   1.  53.   3.  32.   8.  61.   3. ...
# 2      [ 14.   1.  45.   6. 170.  14. 694.  32. 139. ...
# 3      [ 11.   1.   1.  36.   5. 116.  10. 395.  19. ...
# 4      [  7.  16.   2.  83.   5.  38.   7.  34.   2. ...
# ...                                                  ...
# 25684                                                NaN
# 25685                                                NaN
# 25686                                                NaN
# 25687                                                NaN
# 25688                                                NaN
#
# [25689 rows x 41 columns]

# %%
def col_num_not_na(df: pd.DataFrame, col: str):
    return len(df[~df[col].isna()])
def col_num_unique_values(df: pd.DataFrame, col: str):
    return len(df[col].unique())

# %%
print(f'len(df): {len(df)}')
for col in df.columns:
    print(f'---{col}---\n\t Number of entries with "{col}": {col_num_not_na(df, col)}\n\t Number of unique values: {col_num_unique_values(df, col)}')
# Out:
# len(df): 25689
# ---Index---
# 	 Number of entries with "Index": 25689
# 	 Number of unique values: 25689
# ---Name---
# 	 Number of entries with "Name": 25689
# 	 Number of unique values: 25529
# ---Synon---
# 	 Number of entries with "Synon": 203
# 	 Number of unique values: 179
# ---Campaign/Experimental_Source---
# 	 Number of entries with "Campaign/Experimental_Source": 25687
# 	 Number of unique values: 7
# ---Experimental_Conditions---
# 	 Number of entries with "Experimental_Conditions": 20205
# 	 Number of unique values: 22
# ---UID---
# 	 Number of entries with "UID": 25689
# 	 Number of unique values: 25689
# ---Contributor_ID---
# 	 Number of entries with "Contributor_ID": 263
# 	 Number of unique values: 206
# ---Comments---
# 	 Number of entries with "Comments": 4757
# 	 Number of unique values: 1384
# ---Suspected_Matches---
# 	 Number of entries with "Suspected_Matches": 4
# 	 Number of unique values: 5
# ---Confirmed_Matches---
# 	 Number of entries with "Confirmed_Matches": 1
# 	 Number of unique values: 2
# ---Predicted_Matches---
# 	 Number of entries with "Predicted_Matches": 22222
# 	 Number of unique values: 6845
# ---Compound_Structural_Info---
# 	 Number of entries with "Compound_Structural_Info": 4221
# 	 Number of unique values: 46
# ---Formula---
# 	 Number of entries with "Formula": 746
# 	 Number of unique values: 400
# ---MW---
# 	 Number of entries with "MW": 683
# 	 Number of unique values: 230
# ---MW_Prediction---
# 	 Number of entries with "MW_Prediction": 22220
# 	 Number of unique values: 420
# ---ExactMass---
# 	 Number of entries with "ExactMass": 518
# 	 Number of unique values: 369
# ---VUV_Exact_Mass---
# 	 Number of entries with "VUV_Exact_Mass": 0
# 	 Number of unique values: 1
# ---CAS#---
# 	 Number of entries with "CAS#": 159
# 	 Number of unique values: 132
# ---Ch3MS-RF_Cnum.p---
# 	 Number of entries with "Ch3MS-RF_Cnum.p": 24998
# 	 Number of unique values: 23216
# ---Ch3MS-RF_OC.p---
# 	 Number of entries with "Ch3MS-RF_OC.p": 24998
# 	 Number of unique values: 24383
# ---Ch3MS-RF_OSc.p---
# 	 Number of entries with "Ch3MS-RF_OSc.p": 24998
# 	 Number of unique values: 23871
# ---Ch3MS-RF_VP.p---
# 	 Number of entries with "Ch3MS-RF_VP.p": 24998
# 	 Number of unique values: 23861
# ---Column_Type---
# 	 Number of entries with "Column_Type": 25663
# 	 Number of unique values: 3
# ---Retention_index---
# 	 Number of entries with "Retention_index": 25494
# 	 Number of unique values: 3650
# ---d_alkane_RTI---
# 	 Number of entries with "d_alkane_RTI": 25479
# 	 Number of unique values: 2197
# ---n_alkane_RTI---
# 	 Number of entries with "n_alkane_RTI": 25515
# 	 Number of unique values: 2257
# ---Instrument---
# 	 Number of entries with "Instrument": 25687
# 	 Number of unique values: 2
# ---Ionization---
# 	 Number of entries with "Ionization": 25687
# 	 Number of unique values: 4
# ---Injection_method---
# 	 Number of entries with "Injection_method": 25687
# 	 Number of unique values: 2
# ---Derivatization_Agent---
# 	 Number of entries with "Derivatization_Agent": 25687
# 	 Number of unique values: 2
# ---GC_column---
# 	 Number of entries with "GC_column": 25687
# 	 Number of unique values: 2
# ---Oven_temp---
# 	 Number of entries with "Oven_temp": 25687
# 	 Number of unique values: 3
# ---Publications---
# 	 Number of entries with "Publications": 20967
# 	 Number of unique values: 6
# ---Contributor---
# 	 Number of entries with "Contributor": 25689
# 	 Number of unique values: 5
# ---Date_of_Entry---
# 	 Number of entries with "Date_of_Entry": 25684
# 	 Number of unique values: 12
# ---Num Peaks---
# 	 Number of entries with "Num Peaks": 25689
# 	 Number of unique values: 446
# ---5_Highest_Intensity_MZ---
# 	 Number of entries with "5_Highest_Intensity_MZ": 22222
# 	 Number of unique values: 17737
# ---Base_Peak---
# 	 Number of entries with "Base_Peak": 22222
# 	 Number of unique values: 315
# ---MS---
# 	 Number of entries with "MS": 25689
# 	 Number of unique values: 25689
# ---X-Values---
# 	 Number of entries with "X-Values": 22222
# 	 Number of unique values: 22221
# ---Y-Values---
# 	 Number of entries with "Y-Values": 22222
# 	 Number of unique values: 22223

# %%
predicted_matches_not_na = df[~df['Predicted_Matches'].isna()]
predicted_matches_not_list_empty = predicted_matches_not_na['Predicted_Matches'].apply(lambda x: x if '[]' not in x and 'nan' not in x else None)
predicted_matches_not_list_empty = predicted_matches_not_list_empty.apply(lambda x: not isinstance(x, type(None)))
predicted_matches_not_na[predicted_matches_not_list_empty]['Predicted_Matches']
# Out:
# 0                    ['LDY-1094', 'LDY-14785', 'LDY-2330']
# 1                      ['LDY-1092', 'LDY-14775', 'LDY-15']
# 2                                ['LDY-1090', 'LDY-14788']
# 3                                ['LDY-14784', 'LDY-1100']
# 4                                   ['LDY-12', 'LDY-1106']
#                                ...
# 22202                                        ['LDY-14616']
# 22206                ['LDY-7531', 'LDY-21125', 'LDY-6928']
# 22207                                        ['LDY-23006']
# 22209    ['LDY-23423', 'LDY-14720', 'LDY-14706', 'LDY-9...
# 22213                                        ['LDY-22003']
# Name: Predicted_Matches, Length: 6308, dtype: object

# %%
els=[]
for el in df['Predicted_Matches'].unique():
    els.append(type(el))
print(set(els))
# Out:
# {<class 'float'>, <class 'str'>}

# %%
predicted_matches_not_na.tail(5)['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/diffms/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/envs/diffms/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/diffms/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 predicted_matches_not_na.tail(5)['']
#
# File ~/anaconda3/envs/diffms/lib/python3.9/site-packages/pandas/core/frame.py:3506, in DataFrame.__getitem__(self, key)
#    3504 if self.columns.nlevels > 1:
#    3505     return self._getitem_multilevel(key)
# -> 3506 indexer = self.columns.get_loc(key)
#    3507 if is_integer(indexer):
#    3508     indexer = [indexer]
#
# File ~/anaconda3/envs/diffms/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: ''

# %%
formula_df = df[~df['Formula'].isna()][['Name', 'Formula', 'CAS#', 'MW', 'Compound_Structural_Info', 'UID', 'MS', 'X-Values', 'Y-Values']]
formula_df[~formula_df['Compound_Structural_Info'].isna()]
# Out:
#                                        Name      Formula        CAS#       MW  \
# 6754                      pinonic acid, TMS   C13H24O3Si         NaN  256.420
# 6756                    UNK_AHG_LY_APINOX_4   C11H20O4Si         NaN  244.360
# 6763                 pinonaldehyde isomer 2     C10H16O2         NaN  168.240
# 6767               pinonic acid, TMS isomer   C13H24O3Si         NaN  256.420
# 6771   Silanol, trimethyl-, phosphate (3:1)  C9H27O4PSi3  10497-05-9  314.000
# ...                                     ...          ...         ...      ...
# 20004                    UNK_AHG_HZ_SOAS_97      C7H9NO6         NaN      NaN
# 20010                   UNK_AHG_HZ_SOAS_103     C8H11NO6         NaN      NaN
# 20019                   UNK_AHG_HZ_SOAS_112      C6H7NO6         NaN      NaN
# 20024                   UNK_AHG_HZ_SOAS_117  C14H30O4Si2         NaN  318.417
# 20071                   UNK_AHG_HZ_SOAS_164  C14H30O4Si2         NaN  318.417
#
#                                 Compound_Structural_Info        UID  \
# 6754                                      1 of 2 isomers   LDY-6915
# 6756   Underivatized structure propose to contain one...   LDY-6917
# 6763                                      1 of 2 isomers   LDY-6924
# 6767                                      1 of 2 isomers   LDY-6928
# 6771                             3 derivatized OH groups   LDY-6932
# ...                                                  ...        ...
# 20004             Contains N, OH>=2; maybe C7H7NO4(OH)2?  LDY-21212
# 20010              Contains N, OH>=2; maybe C8H9NO4(OH)2  LDY-21218
# 20019                         OH >=2; maybe C6H4NO3(OH)3  LDY-21227
# 20024                                        2 OH groups  LDY-21232
# 20071                                        2 OH groups  LDY-21279
#
#                                                       MS  \
# 6754   29 2.0 ; 39 16.0 ; 40 2.0 ; 41 40.0 ; 42 5.0 ;...
# 6756   29 2.0 ; 31 2.0 ; 38 1.0 ; 39 26.0 ; 40 5.0 ; ...
# 6763   29 13.0 ; 31 1.0 ; 37 2.0 ; 38 6.0 ; 39 79.0 ;...
# 6767   29 10.0 ; 30 1.0 ; 31 3.0 ; 37 1.0 ; 38 2.0 ; ...
# 6771   29 1.0 ; 31 1.0 ; 42 1.0 ; 43 10.0 ; 44 8.0 ; ...
# ...                                                  ...
# 20004  31 2.0 ; 40 1.0 ; 41 6.0 ; 42 4.0 ; 43 244.0 ;...
# 20010  29 3.0 ; 30 1.0 ; 31 2.0 ; 32 1.0 ; 33 1.0 ; 3...
# 20019  29 40.0 ; 30 1.0 ; 31 2.0 ; 32 4.0 ; 33 1.0 ; ...
# 20024  29 9.0 ; 30 1.0 ; 31 2.0 ; 36 1.0 ; 37 1.0 ; 3...
# 20071  29 6.0 ; 31 2.0 ; 32 1.0 ; 34 2.0 ; 38 2.0 ; 3...
#
#                                                 X-Values  \
# 6754   [ 29.  39.  40.  41.  42.  43.  44.  45.  46. ...
# 6756   [ 29.  31.  38.  39.  40.  41.  42.  43.  44. ...
# 6763   [ 29.  31.  37.  38.  39.  40.  41.  42.  43. ...
# 6767   [ 29.  30.  31.  37.  38.  39.  40.  41.  42. ...
# 6771   [ 29.  31.  42.  43.  44.  45.  46.  47.  49. ...
# ...                                                  ...
# 20004  [ 31.  40.  41.  42.  43.  44.  45.  46.  47. ...
# 20010  [ 29.  30.  31.  32.  33.  39.  40.  41.  42. ...
# 20019  [ 29.  30.  31.  32.  33.  34.  35.  36.  37. ...
# 20024  [ 29.  30.  31.  36.  37.  38.  39.  40.  41. ...
# 20071  [ 29.  31.  32.  34.  38.  39.  40.  41.  42. ...
#
#                                                 Y-Values
# 6754   [  2.  16.   2.  40.   5. 125.  10.  61.   4. ...
# 6756   [  2.   2.   1.  26.   5.  57.  12.  82.  13. ...
# 6763   [ 13.   1.   2.   6.  79.  12. 218.  24. 452. ...
# 6767   [ 10.   1.   3.   1.   2.  36.   5. 117.  19. ...
# 6771   [  1.   1.   1.  10.   8.  80.   4.  10.   1. ...
# ...                                                  ...
# 20004  [  2.   1.   6.   4. 244.  16.  90.   2.  27. ...
# 20010  [  3.   1.   2.   1.   1.   8.   3.  29.   7. ...
# 20019  [ 40.   1.   2.   4.   1.   2.   2.   2.   3. ...
# 20024  [  9.   1.   2.   1.   1.   2.  16.   4.  71. ...
# 20071  [  6.   2.   1.   2.   2.  29.   7. 104.  15. ...
#
# [225 rows x 9 columns]
